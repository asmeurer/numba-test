# %%
import os; os._exit(1) # Restart the kernel

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.kernel.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %run test.py 0
# Out:
# <function <lambda> at 0x10bf891b8>
# generating checkerboard
# took
#  1.18721699715
# generating squares
# took 0.00476717948914
# finding corners
# took
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/aaronmeurer/Documents/ipython/IPython/utils/py3compat.pyc in execfile(fname, *where)
#     202             else:
#     203                 filename = fname
# --> 204             __builtin__.execfile(filename, *where)
#
# /Users/aaronmeurer/Documents/Continuum/numba-test/test.py in <module>()
#      66 t = time.time()
#      67
# ---> 68 coords_subpix = corner_subpix(image, coords, 13, 0.99)
#      69
#      70 print "took", time.time() - t
#
# /Users/aaronmeurer/anaconda/envs/numba-tests/lib/python2.7/site-packages/numba/numbawrapper.so in numba.numbawrapper._NumbaSpecializingWrapper.__call__ (numba/numbawrapper.c:3726)()
#
# ...

# %%
# %run test.py 1
# Out:
# using autojit
# <function autojit at 0x10cb632a8>
# generating checkerboard
# took
#  1.33338189125
# generating squares
# took 8.01086425781e-05
# finding corners
# took
#  9.66339921951
# plotting

# %%
# %run test.py 2
# Out:
# using autojit
# <function autojit at 0x10d0d3aa0>
# generating checkerboard
# took
#  1.12232303619
# generating squares
# took 0.000191926956177
# finding corners
# took
#  8.73882818222
# plotting

# %%
times = 0.00575304031372, 5.19752502441e-05, 0.000191926956177

# %%
times[0]/times[1]
# Out:
# 110.68807339456839

# %%
times[0]/times[2]
# Out:
# 29.975155279461617

# %%
times[2]/times[1]
# Out:
# 3.6926605504662615
